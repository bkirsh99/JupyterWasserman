# %% [markdown]
# # Task 3: Identify Cis-Regulatory Elements Within the ACE2 TAD
# - Identify cis-regulatory regions within the smaller ACE2 TAD based on bidning indicators
#
# 1) ENCODE/ReMap/UniBind: **Plot TF peaks**
#
# a) [ENCODE](https://www.encodeproject.org/)
# b) [ReMap](http://remap.univ-amu.fr/)
# c) [UniBind](https://unibind.uio.no/)
#
# 2) Segway/ChromHMM: **Predict the location of regulatory regions**
#
# a) [Segway](https://pmgenomics.ca/hoffmanlab/proj/segway/)
# b) [ChromHMM](http://compbio.mit.edu/ChromHMM/)
#
# - Related articles:
# 1) [Identifying regulatory elements in eukaryotic genomes](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2764519/)
#
# # Glossary of Cis-Regulatory Elements:
# ## Promoters:
# - Found in proximity to the TSS
# - Contain binding sites for ubiqutous GTFs or for activator proteins that interact with the GTFs
#
# ## Enchancers:
# -  Found at a greater distance from the TSS, either upstream or downstream of the gene or within an intron
#
# ## Silencers:
# - Can be present within enhancers or can act as independent modules with binding sites for repressors
#
# ## Insulators:
# - Usually contain multiple binding sites for TFs and the strength is directly proportional to the number of binding sites
#
# # Step-By-Step Walkthrough:
# ## 1) Determine the 3'- and 5'-edges:
# ![annotateducsc.png](attachment:annotateducsc.png)
# **Rationale:** The main outliers, i.e. lung (F), small intestine (F), and bladder (M), were excluded and the 3'- and 5'-edges were determined by the median values of the sex-independent distribution.
# - ***3'-edge (crhomStart):*** chrX:15,250,000 (i.e. chrX:15,509,068 - 259,068 bp)
# - ***5'-edge (chromEnd):*** chrX:15,750,000 (i.e. chrX:15,509,068 + 240,932 bp)
# ![Rplot-task3.png](attachment:Rplot-task3.png)

# %% [raw]
# Data2 <- subset(Data, chromEnd < 16400000)
#
# bp52 <- ggplot(data=Data2,aes(x=Sex,y=d5/1000))+geom_boxplot(outlier.colour="blue",outlier.shape=1,outlier.size=3)+geom_jitter(width=0.1)+stat_summary(fun=mean, colour="red", geom="point",shape=18, size=5,show.legend = FALSE)+labs(title="5'-Distance to Reference Point (kb)",x="Sex",y="5'-Edge Distance (kb)")
# bp32 <- ggplot(data=Data2,aes(x=Sex,y=d3/1000))+geom_boxplot(outlier.colour="blue",outlier.shape=1,outlier.size=3)+geom_jitter(width=0.1)+stat_summary(fun=mean, colour="red", geom="point",shape=18, size=5,show.legend = FALSE)+labs(title="3'-Distance to Reference Point (kb)",x="Sex",y="3'-Edge Distance (kb)")
# bpgen2 <- boxplot(Data2$d5/1000,Data2$d3/1000,main="Sex-Independent Distance to Reference Point (kb)",at=c(1,2),names=c("5'-edge Distance","3'-edge Distance"),cex=0.5)
#
# ggplot_build(bp52)$data
# ggplot_build(bp32)$data
# bpgen2

# %% [markdown]
# ![just-task3.PNG](attachment:just-task3.PNG)

# %% [markdown]
# # UniBind:
# ## [UCSC Genome Browser](http://genome.ucsc.edu/cgi-bin/hgTracks?db=hg38&hubUrl=https://unibind.uio.no/static/UniBind_hubs/hub.txt)
# ![task3-1.PNG](attachment:task3-1.PNG)
#
# 1) Using the Table Browser and UniBind Track, obtain an output with all TFs for the desired region:
# ![task3-2.PNG](attachment:task3-2.PNG)
#
# 2) Using Excel, obtain the name of each TF according to UniBind's naming convention <GEO/ArrayExpress/ENCODE identifier>.<cell type/tissue>_<condition>.<TF name>.<JASPAR ID>.<JASPAR version>.<TF binding model>
#     **TF name** =MID(D2,(SEARCH(".",D2,SEARCH(".",D2)+1)+1),((SEARCH(".",D2,SEARCH(".",D2,(SEARCH(".",D2)+1)+1)+1)-(SEARCH(".",D2,SEARCH(".",D2)+1)+1))))
#     ![TASK3-3.PNG](attachment:TASK3-3.PNG)
#
# 3) Using R, plot revelant data:

# %% [raw]
# library(readxl)
# tfs_ace2_tad <- read_excel("Wasserman/tfs-ace2-tad.xlsx")
# DataTF <- tfs_ace2_tad
#
# library(dplyr)
# TFfreq <- DataTF %>% group_by(TF) %>% summarise(counts=n())
#
# library(ggplot2)
# ggplot(DataTF, aes(TF))+geom_bar()

# %% [markdown]
# ![task3-4.PNG](attachment:task3-4.PNG)

# %% [raw]
# sTFordered <- TFfreq[order(TFfreq$counts,decreasing = FALSE),]
# barplot(height=TFordered$counts,names.arg = TFordered$TF,horiz = T,las=1,cex.names=0.5)
#
# # Group TFs as a function of count:
# countTF <- aggregate(TFordered$TF~TFordered$counts,FUN=c)
#
# # Rename columns:
# names(countTF)[names(countTF)=="TFordered$counts"] <- "Count"
# names(countTF)[names(countTF)=="TFordered$TF"] <- "TFs"
#
# library(RColorBrewer)
# n <- 52
# colour <- colorRampPalette(brewer.pal(11,"Spectral"))(n)
# palette(colour)
# barplot(height=countTF$Count,names.arg=countTF$Count,main="Count Distribution of Transcription Factors (TFs)", sub = "Transcription Factors Grouped According to Frequency Within the ACE2 TAD", legend.text=as.graphicsAnnot(countTF$TFs),args.legend=list(title="Transcription Factors",x="right",cex=0.5),horiz = T,col=factor(countTF$Count),las=1,cex.names=0.7)

# %% [markdown]
# ![Rplot-T3-TF.png](attachment:Rplot-T3-TF.png)

# %% [raw]
# library(ggplot2)
# pie(countTF$Count,labels=countTF$TFs,col=colour) # This doesn't work too well since labels tend to overlap
#
# library(plotly)
# plot_ly(countTF,labels=~TFs,values=~Count,type="pie",textposition="outside",textinfo="label", showlegend=FALSE)%>%layout(title="Count Distribution of Transcription Factors (TFs)",xaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE), yaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE),margin=list(t=50,b=300,r=1500,l=50,pad=0))

# %% [markdown]
# ![tfs.PNG](attachment:tfs.PNG)

# %% [markdown]
# # Bioconductor

# %% [markdown]
# if (!requireNamespace("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")
# BiocManager::install(version = "3.11")

# %% [markdown]
# # Identifying TF Peaks:
# ![meeting28.PNG](attachment:meeting28.PNG)

# %% [raw]
# ace2start <- 15561033
# ace2end <- 15602158
#
# hist(DataTF$chromStart,main="Histogram of TF Distribution", xlab="Genomic Coordinates of Chromosomal Interactions",xlim=c(15250000,15750000),n=10000)
# segments(ace2start,0,ace2end,0,col="red",lwd=5)
# legend("topright",legend=c("ACE2"),col=c("red"),lty=1:2,cex=0.8)

# %% [markdown]
# # Predicting the Location of Regulatory Regions:
# 1. Using FANTOM5:
# ![FANTOM5.1.PNG](attachment:FANTOM5.1.PNG)
# ![FANTOM5.2.PNG](attachment:FANTOM5.2.PNG)
#
# 2. Using UCSC for a combined analysis of chromatin events and TF-binding events:
# ![t3-all.PNG](attachment:t3-all.PNG)
